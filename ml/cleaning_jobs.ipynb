# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/capstone-jobs-dataset/jobs_dataset.csv

# %%
df = pd.read_csv('/kaggle/input/capstone-jobs-dataset/jobs_dataset.csv').sample(frac=1).reset_index(drop=True)
df
# Out:
#                                        Title                         Company  \
# 0            QA Engineer (Credit) - Sea Labs                             Sea
# 1                                  QA Manual                  Asuransi Astra
# 2                SOC Manager (Project Based)                      Lintasarta
# 3                    IT Security (Blue Team)  Indocyber Global Teknologi, PT
# 4                          Quality Assurance                           Monee
# ...                                      ...                             ...
# 5246  Field Service Engineer Staff - Jakarta        PT. Medquest Jaya Global
# 5247                         Digital Finance              PT Lion Super Indo
# 5248              Quality Control Technician                         Vascomm
# 5249                Indonesia - Country Head                        POP MART
# 5250    QA Engineer (Marketplace) - Sea Labs                        Bibit.id
#
#                                Location     Country  \
# 0                    Jakarta, Indonesia   Indonesia
# 1            Gambir, Jakarta, Indonesia   Indonesia
# 2                    Jakarta, Indonesia   Indonesia
# 3           Jakarta, Jakarta, Indonesia   Indonesia
# 4                    Jakarta, Indonesia   Indonesia
# ...                                 ...         ...
# 5246        Jakarta, Jakarta, Indonesia   Indonesia
# 5247  South Jakarta, Jakarta, Indonesia   Indonesia
# 5248    Cileungsi, West Java, Indonesia   Indonesia
# 5249                 Jakarta, Indonesia   Indonesia
# 5250                 Jakarta, Indonesia   Indonesia
#
#                                         Job Description  \
# 0     Be involved in whole development life cycle an...
# 1                                             Not Found
# 2     Lead and manage the SOC team, ensuring 24/7 mo...
# 3     Analyze and respond to security incidents incl...
# 4                                             Not Found
# ...                                                 ...
# 5246                                          Not Found
# 5247  Ability to adapt to and manage change effectiv...
# 5248                                          Not Found
# 5249  We are looking for a proactive, assertive, tak...
# 5250  Define and analyze metrics to guide product de...
#
#                                        Job Requirements  \
# 0     Functional testing via grey-box and white-box ...
# 1     Membuat analisa dan menyimpulkan jumlah temuan...
# 2     Oversee the deployment and operation of securi...
# 3     Perform configuration setup on security device...
# 4     Checking collection process and makesure suita...
# ...                                                 ...
# 5246  Install, maintain, and perform preventive main...
# 5247  Bachelor’s degree in Accounting, Finance, Info...
# 5248  Responsible for software testing (manually) ac...
# 5249  Resolves issues effectively seeing real proble...
# 5250  Understand markets, industry landscapes, and u...
#
#                                                    Link
# 0     https://id.linkedin.com/jobs/view/qa-engineer-...
# 1     https://id.linkedin.com/jobs/view/automotive-q...
# 2     https://id.linkedin.com/jobs/view/soc-manager-...
# 3     https://id.linkedin.com/jobs/view/it-security-...
# 4     https://id.linkedin.com/jobs/view/quality-assu...
# ...                                                 ...
# 5246  https://id.linkedin.com/jobs/view/field-servic...
# 5247  https://id.linkedin.com/jobs/view/digital-fina...
# 5248  https://id.linkedin.com/jobs/view/qa-manual-fr...
# 5249  https://id.linkedin.com/jobs/view/indonesia-co...
# 5250  https://id.linkedin.com/jobs/view/product-mana...
#
# [5251 rows x 7 columns]

# %%
# Ganti "Not Found" dengan NaN
df.replace("Not Found", np.nan, inplace=True)

# %%
# Hapus duplikat
df.drop_duplicates(subset=["Title", "Company", "Location"], inplace=True)

# %%
df
# Out:
#                                 Title                         Company  \
# 0     QA Engineer (Credit) - Sea Labs                             Sea
# 1                           QA Manual                  Asuransi Astra
# 2         SOC Manager (Project Based)                      Lintasarta
# 3             IT Security (Blue Team)  Indocyber Global Teknologi, PT
# 4                   Quality Assurance                           Monee
# ...                               ...                             ...
# 5232  Assistant Director of Marketing       Indepay | Setara Networks
# 5233         Operational Risk Analyst                 Astra Financial
# 5236                   Tax Accountant                  Ahti Interiors
# 5241    International Sales Executive    Marriott Vacations Worldwide
# 5248       Quality Control Technician                         Vascomm
#
#                              Location     Country  \
# 0                  Jakarta, Indonesia   Indonesia
# 1          Gambir, Jakarta, Indonesia   Indonesia
# 2                  Jakarta, Indonesia   Indonesia
# 3         Jakarta, Jakarta, Indonesia   Indonesia
# 4                  Jakarta, Indonesia   Indonesia
# ...                               ...         ...
# 5232                  Bali, Indonesia   Indonesia
# 5233               Jakarta, Indonesia   Indonesia
# 5236      Jakarta, Jakarta, Indonesia   Indonesia
# 5241        Denpasar, Bali, Indonesia   Indonesia
# 5248  Cileungsi, West Java, Indonesia   Indonesia
#
#                                         Job Description  \
# 0     Be involved in whole development life cycle an...
# 1                                                   NaN
# 2     Lead and manage the SOC team, ensuring 24/7 mo...
# 3     Analyze and respond to security incidents incl...
# 4                                                   NaN
# ...                                                 ...
# 5232  Partner with the brand and analytics team to p...
# 5233  Monitor Astra Financial's business unit in car...
# 5236  Prepare and analyze monthly, quarterly, and an...
# 5241                                                NaN
# 5248                                                NaN
#
#                                        Job Requirements  \
# 0     Functional testing via grey-box and white-box ...
# 1     Membuat analisa dan menyimpulkan jumlah temuan...
# 2     Oversee the deployment and operation of securi...
# 3     Perform configuration setup on security device...
# 4     Checking collection process and makesure suita...
# ...                                                 ...
# 5232  5+ years of demonstrated experience in product...
# 5233  S1 from finance, accounting, mathematics, stat...
# 5236  Maintain the general ledger and ensure all tra...
# 5241                                                NaN
# 5248  Responsible for software testing (manually) ac...
#
#                                                    Link
# 0     https://id.linkedin.com/jobs/view/qa-engineer-...
# 1     https://id.linkedin.com/jobs/view/automotive-q...
# 2     https://id.linkedin.com/jobs/view/soc-manager-...
# 3     https://id.linkedin.com/jobs/view/it-security-...
# 4     https://id.linkedin.com/jobs/view/quality-assu...
# ...                                                 ...
# 5232  https://id.linkedin.com/jobs/view/product-mark...
# 5233  https://id.linkedin.com/jobs/view/operational-...
# 5236  https://id.linkedin.com/jobs/view/accountant-a...
# 5241  https://id.linkedin.com/jobs/view/internationa...
# 5248  https://id.linkedin.com/jobs/view/qa-manual-fr...
#
# [2004 rows x 7 columns]

# %%
df_cleaned = df.dropna(subset=["Job Description", "Job Requirements"])

# %%
df_cleaned
# Out:
#                                  Title                         Company  \
# 0      QA Engineer (Credit) - Sea Labs                             Sea
# 2          SOC Manager (Project Based)                      Lintasarta
# 3              IT Security (Blue Team)  Indocyber Global Teknologi, PT
# 6     Country Product Development Lead                             UPL
# 7                  Junior Art Director                     Neo Digital
# ...                                ...                             ...
# 5220  Finance, Accounting, & Tax Staff                              EY
# 5230                  Process Engineer    PT. Erajaya Swasembada, Tbk.
# 5232   Assistant Director of Marketing       Indepay | Setara Networks
# 5233          Operational Risk Analyst                 Astra Financial
# 5236                    Tax Accountant                  Ahti Interiors
#
#                                    Location     Country  \
# 0                        Jakarta, Indonesia   Indonesia
# 2                        Jakarta, Indonesia   Indonesia
# 3               Jakarta, Jakarta, Indonesia   Indonesia
# 6               Jakarta, Jakarta, Indonesia   Indonesia
# 7            Cengkareng, Jakarta, Indonesia   Indonesia
# ...                                     ...         ...
# 5220  Grogol Petamburan, Jakarta, Indonesia   Indonesia
# 5230      Semarang, Central Java, Indonesia   Indonesia
# 5232                        Bali, Indonesia   Indonesia
# 5233                     Jakarta, Indonesia   Indonesia
# 5236            Jakarta, Jakarta, Indonesia   Indonesia
#
#                                         Job Description  \
# 0     Be involved in whole development life cycle an...
# 2     Lead and manage the SOC team, ensuring 24/7 mo...
# 3     Analyze and respond to security incidents incl...
# 6     Define and implement product development plans...
# 7     Bachelor's degree in Visual Communication Desi...
# ...                                                 ...
# 5220  Obtain, analyze and evaluate the existing FA’s...
# 5230  Managing Product with Demand Planning (tactica...
# 5232  Partner with the brand and analytics team to p...
# 5233  Monitor Astra Financial's business unit in car...
# 5236  Prepare and analyze monthly, quarterly, and an...
#
#                                        Job Requirements  \
# 0     Functional testing via grey-box and white-box ...
# 2     Oversee the deployment and operation of securi...
# 3     Perform configuration setup on security device...
# 6     Monitor competitor activity and emerging agron...
# 7     Fast Learner and Adaptable, can follow digital...
# ...                                                 ...
# 5220  Perform & control the Finance and Accounting (...
# 5230  Managing Product Gross Profit to maximize retu...
# 5232  5+ years of demonstrated experience in product...
# 5233  S1 from finance, accounting, mathematics, stat...
# 5236  Maintain the general ledger and ensure all tra...
#
#                                                    Link
# 0     https://id.linkedin.com/jobs/view/qa-engineer-...
# 2     https://id.linkedin.com/jobs/view/soc-manager-...
# 3     https://id.linkedin.com/jobs/view/it-security-...
# 6     https://id.linkedin.com/jobs/view/country-prod...
# 7     https://id.linkedin.com/jobs/view/junior-art-d...
# ...                                                 ...
# 5220  https://id.linkedin.com/jobs/view/cbs-internal...
# 5230  https://id.linkedin.com/jobs/view/merchandisin...
# 5232  https://id.linkedin.com/jobs/view/product-mark...
# 5233  https://id.linkedin.com/jobs/view/operational-...
# 5236  https://id.linkedin.com/jobs/view/accountant-a...
#
# [1365 rows x 7 columns]

# %%
df_cleaned.to_csv('jobs_cleaned.csv', index=False)
